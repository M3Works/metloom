# %% [raw]
# # Snow Course Data

# %%
from datetime import datetime
from metloom.pointdata import SnotelPointData

# %%
pt = SnotelPointData("17A07:WA:SNOW", "Baird #2")

start_date = datetime(2024, 12, 1)
end_date = datetime(2025, 2, 1)
variables = [pt.ALLOWED_VARIABLES.SWE]

df = pt.get_snow_course_data(start_date, end_date, variables)
df
# Out:
# Could not find timezone info for 17A07:WA:SNOW (Baird #2)
#                                                                   geometry  \
# datetime                  site
# 2025-01-30 00:00:00+00:00 17A07:WA:SNOW  POINT Z (-117.55251 48.6067 3170)
#
#                                                   measurementDate  SWE  \
# datetime                  site
# 2025-01-30 00:00:00+00:00 17A07:WA:SNOW 2025-01-30 00:00:00+00:00  4.6
#
#                                         SWE_units datasource
# datetime                  site
# 2025-01-30 00:00:00+00:00 17A07:WA:SNOW        in       NRCS
